# %% [markdown]
# mount google drive and authenticate to access files

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# check the currect directory content

# %%
! ls
# Out:
# ColabSettingAndAccess.ipynb  experiments     ML-CWs
# DownloadImageSave.ipynb      HomePrediction  super-resolution-master

# %% [markdown]
# change directory to specific dir

# %%
# %cd gdrive/MyDrive/'Collaborate '
# Out:
# /content/gdrive/MyDrive/Collaborate

# %% [markdown]
# install any package if missing

# %%
#! pip install <desired-python-library>

# %% [markdown]
# check the access of any file

# %% [markdown]
# # downloading and saving locally

# %%
pip install mysql.connector
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 84.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp38-cp38-linux_x86_64.whl size=247965 sha256=82fdf7026ed4ff4bb9e361eba2372693b52151657f9d65b37b54a34c2db05d60
#   Stored in directory: /root/.cache/pip/wheels/57/e4/98/5feafb5c393dd2540e44b064a6f95832990d543e5b4f53ea8f
# Successfully built mysql.connector
# ...

# %%
#Getting the data from the GCP Users Sample
import cv2
from PIL import Image
import urllib.request
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#importing deepface library and DeepFace
import mysql.connector
from datetime import datetime
import time

# %%
print('start at: ' + str(datetime.now()))


mydb = mysql.connector.connect(
            host = "34.89.45.238",
            user = "root",
            password = "mysql@123",
            database = "AirBnb"
        )
cursor = mydb.cursor()
#query = "SELECT * FROM airbnb_listing_host where picture_large_url is not null limit 0, 1000;"
query = "SELECT * FROM AirBnb.airbnb_listing_users_sample;"
cursor.execute(query)
 
myresult = cursor.fetchall()
# Out:
# start at: 2023-01-07 21:55:41.165906

# %%
import requests # request img from web
import shutil # save img locally

# %%
url = 'https://a0.muscache.com/im/pictures/user/d8c0118f-b613-4af9-b2a9-05af2c769a5d.jpg'
file_name = '10132289' #prompt user for file name

# %%
res = requests.get(url, stream = True)
if res.status_code == 200:
  with open(file_name,'wb') as f:
    shutil.copyfileobj(res.raw, f)
    print('Image sucessfully Downloaded: ',file_name)
else:
    print('Image Couldn\'t be retrieved')
# Out:
# Image sucessfully Downloaded:  10132289

# %%
print(myresult)
# Out:
# [('10132289', 'David', None, 'https://a0.muscache.com/im/pictures/user/d8c0118f-b613-4af9-b2a9-05af2c769a5d.jpg', 'man', '50', 'white', None, None, None), ('103282630', 'Carlos', None, 'https://a0.muscache.com/im/pictures/user/97c04b54-491d-42b7-a67b-b8b6162ed051.jpg', 'man', '35', 'middle eastern', None, None, None), ('111817408', 'Quintessa', None, 'https://a0.muscache.com/im/pictures/user/8a70a596-abac-462c-94d9-3a2424003004.jpg', 'woman', '25', 'black', None, None, None), ('111965190', 'David', None, 'https://a0.muscache.com/im/pictures/user/906ee7e0-2dbc-4e78-a4b8-f4415f65e97c.jpg', 'man', '45', 'white', None, None, None), ('11249362', 'Mustanir', None, 'https://a0.muscache.com/im/pictures/user/459893c5-0abc-496a-879f-b4997340d410.jpg', 'man', '30', 'middle eastern', None, None, None), ('113049444', 'Ismail', None, 'https://a0.muscache.com/im/pictures/user/3c24b67f-d09f-4d4f-987a-2f687da7348b.jpg', 'man', '40', 'black', None, None, None), ('1185890', 'Barbara', None, 'https://a0
# ...

# %%
count = 0
df = pd.DataFrame(myresult)
print(df.columns.values)
for x in myresult:
    url = x[3]
    file_name = x[0] #prompt user for file name
    res = requests.get(url, stream = True)
    if res.status_code == 200:
      with open(file_name,'wb') as f:
        shutil.copyfileobj(res.raw, f)
      print('Image sucessfully Downloaded: ',file_name)
    else:
      print('Image Couldn\'t be retrieved')
    count+=1

# %% [markdown]
# # if file name and path is present

# %%
import urllib2

def download_image(url):
    request = urllib2.Request(url)
    img = urllib2.urlopen(request).read()
    with open (file_name + '.jpg', 'w') as f: f.write(img)

url = input('Please enter image URL (string):')
file_name = input('Please enter file name (string):')

download_image(url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-f25ee3122eec> in <module>
# ----> 1 import urllib2
#       2
#       3 def download_image(url):
#       4     request = urllib2.Request(url)
#       5     img = urllib2.urlopen(request).read()
#
# ModuleNotFoundError: No module named 'urllib2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # just downloading image

# %%
import wget

url = input('Please enter image URL (string):')

file_name = wget.download(url)

print('Image Successfully Downloaded: ', file_name)
